# %%
from openpyxl import load_workbook
import pandas as pd
import time
from datetime import datetime
import re
from collections import defaultdict
import os
from itertools import groupby

# %% [markdown]
# #### Project: These set of functions together take an excel file that tracks a certain cell line growth in our lab and converts it into a dataframe format.

# %%
### Step 1: Classify sheet as 'good' format or 'bad' format

# %%
### Step 2: For a good format sheet, On column b, look for the second date on that column. Look for uninterrupted chains of numbers where the chain length is divisble by 3 on that row with the date. 
##Once you've identified the chains, split that chain up. 
## If the chain is more than 1 cell from the date then don't proceed.
### Save the date, save the file name, get the passage from the sheet name. v1 you get from the first 3 in thatchain
### v2 you get from the second and v3 the third. The letter comes from counting the first multiple of the chain
#### Save that data in a dataframe.

# %%
def load_workbooks(folder_path): #Loads all workbooks in a folder 
    workbooks = []
    for filename in os.listdir(folder_path):
        if filename.endswith(('.xlsx', '.xlm')) and not filename.startswith('~$'):
            path = os.path.join(folder_path, filename)
            wb = load_workbook(path)
            workbooks.append({'filename': filename, 'path': path, 'workbook': wb})
    return workbooks

# %%
def parse_gbx_string(s):
    match = re.match(r'^GBX(\d+)P(\d+)', s)
    if not match:
        raise ValueError(f"String '{s}' doesn't match expected GBX###P# format")
    
    model_number = match.group(1)
    passage_number = match.group(2)
    
    return model_number, passage_number

def get_model_number(s):
    return parse_gbx_string(s)[0]

def get_passage_number(s):
    return parse_gbx_string(s)[1]

# %%
def group_numbers(nums):
    trimmed = nums[:-4]
    result = {}
    for i, val in enumerate(trimmed):
        letter = chr(ord('A') + i // 3)
        result.setdefault(letter, []).append(val)

    # Drop any key whose group has a None, or doesn't have exactly 3 values
    result = {
        k: v for k, v in result.items()
        if len(v) == 3 and None not in v
    }
    return result

# %%
gaussia_values = []
model_id = 686
passage = 0
workbooks = load_workbooks('./sgluc_files') # Loading all workbooks the sgluc folder into the 'workbooks' list 
rows = []
for item in workbooks:
    print(item['filename'])
    print(item['workbook'].sheetnames)
    gluc_file = item['filename']
    sheets = item['workbook'].sheetnames
    for name in sheets:                    
        ws = item['workbook'][name]
        for cell in ws["B"]:
            if isinstance(cell.value, datetime):   # Check for the first date in column B, most excel files have the dates in column B
                print(f"Datetime in {name}: {cell.value} at {cell.coordinate}")
                input_date = cell.value
                neighbor = ws.cell(row=cell.row, column=cell.column + 1) # Check if the next cell over is a date. If so continue.
                if isinstance(neighbor.value, (int, float)): 
                    offset = 1
                    while True: 
                        num = ws.cell(row=cell.row, column=cell.column + offset) # Get all sequential values into a list 
                        if isinstance(num.value, (int, float)):
                            gaussia_values.append(num.value)
                            offset += 1
                        else:
                            break
                    mice = group_numbers(gaussia_values)
                    for designation, values in mice.items():
                        value1, value2, value3 = values
                        if(value1 == None):
                            continue
                        rows.append({
                            'model': model_id,
                            'passage': passage,
                            'date': input_date,
                            'designation': designation,
                            'value1': value1,
                            'value2': value2,
                            'value3': value3,
                        })
                    gaussia_values = []
                    print("Sheet finished")
# Out:
# GS686-sGluc.xlsx
# ['GBX686P0', 'GBX686P1']
# Datetime in GBX686P0: 2025-07-02 00:00:00 at B10
# Datetime in GBX686P0: 2025-07-22 00:00:00 at B11
# Sheet finished
# Datetime in GBX686P0: 2025-08-06 00:00:00 at B12
# Sheet finished
# Datetime in GBX686P0: 2025-08-20 00:00:00 at B13
# Sheet finished
# Datetime in GBX686P0: 2025-09-03 00:00:00 at B14
# Sheet finished
# Datetime in GBX686P0: 2025-09-17 00:00:00 at B15
# Sheet finished
# Datetime in GBX686P0: 2025-10-01 00:00:00 at B16
# Sheet finished
# Datetime in GBX686P0: 2025-10-15 00:00:00 at B17
# Sheet finished
# Datetime in GBX686P0: 2025-10-22 00:00:00 at B18
# Sheet finished
# Datetime in GBX686P0: 2025-10-29 00:00:00 at B19
# Sheet finished
# Datetime in GBX686P0: 2025-11-05 00:00:00 at B20
# Sheet finished
# Datetime in GBX686P0: 2025-11-12 00:00:00 at B21
# Sheet finished
# Datetime in GBX686P0: 2025-11-19 00:00:00 at B22
# Sheet finished
# Datetime in GBX686P0: 2025-11-26 00:00:00 at B23
# Sheet finished
# Datetime in GBX686P0: 2025-12-03 00:00:00 at B24
# Sheet finished
# Datetime in GBX686P0: 2025-12-10 00:00:00 at B25
# Sheet finished
# Datetime in GBX686P0: 2025-12-17 00:00:00 at B26
# Sheet finished
# Datetime in GBX686P0: 2025-12-31 00:00:00 at B27
# Datetime in GBX686P0: 2026-01-07 00:00:00 at B28
# Datetime in GBX686P0: 2026-01-21 00:00:00 at B29
# Datetime in GBX686P0: 2026-01-28 00:00:00 at B30
# Datetime in GBX686P0: 2026-02-04 00:00:00 at B31
# Datetime in GBX686P0: 2026-02-11 00:00:00 at B32
# Datetime in GBX686P0: 2026-02-18 00:00:00 at B33
# Datetime in GBX686P0: 2026-02-25 00:00:00 at B34
# Datetime in GBX686P0: 2026-03-04 00:00:00 at B35
# Datetime in GBX686P0: 2026-03-11 00:00:00 at B36
# Datetime in GBX686P0: 2026-03-18 00:00:00 at B37
# Datetime in GBX686P0: 2026-04-01 00:00:00 at B38
# Datetime in GBX686P0: 2026-04-08 00:00:00 at B39
# Datetime in GBX686P0: 2026-04-15 00:00:00 at B40
# Datetime in GBX686P0: 2026-05-01 00:00:00 at B41
# Datetime in GBX686P0: 2026-05-06 00:00:00 at B42
# Datetime in GBX686P0: 2026-05-13 00:00:00 at B43
# Datetime in GBX686P0: 2026-05-20 00:00:00 at B44
# Datetime in GBX686P0: 2026-05-27 00:00:00 at B45
# Datetime in GBX686P0: 2026-06-03 00:00:00 at B46
# Datetime in GBX686P0: 2026-06-10 00:00:00 at B47
# Datetime in GBX686P1: 2026-05-21 00:00:00 at B10
# Datetime in GBX686P1: 2026-06-10 00:00:00 at B11
# Sheet finished
# Datetime in GBX686P1: 2026-06-24 00:00:00 at B12
# Sheet finished
# Datetime in GBX686P1: 2026-07-10 00:00:00 at B13
# Sheet finished

# %%
print(mice)
# Out:
# {'A': [1675, 1610, 1850], 'B': [3025, 3250, 3435]}

# %%
from datetime import datetime

gaussia_values = []
workbooks = load_workbooks('./sgluc_files')  # Loading all workbooks in the sgluc folder into 'workbooks'
rows = []

for item in workbooks:
    #print(item['filename'])
    #print(item['workbook'].sheetnames)
    gluc_file = item['filename']
    sheets = item['workbook'].sheetnames
    for name in sheets:
        ws = item['workbook'][name]
        model_id = get_model_number(ws.title)
        passage = get_passage_number(ws.title)
        #print(ws.title)
        for cell in ws["B"]:
            if isinstance(cell.value, datetime):  # Check for the first date in column B
                #print(f"Datetime in {name}: {cell.value} at {cell.coordinate}")
                input_date = cell.value
                row_num = cell.row

                # Check first 9 real-data columns (C onward, skipping A and the date in B)
                first_nine = [ws.cell(row=row_num, column=c).value for c in range(3, 12)]
                if not any(isinstance(v, (int, float)) for v in first_nine):
                    print(f"Row {row_num} has no numeric values in first 9 columns, skipping")
                    continue

                for col_index in range(1, ws.max_column + 1):
                    target_cell = ws.cell(row=row_num, column=col_index)
                    #print(target_cell.value)

                    if col_index <= 2:   # skip column A and column B (the date column)
                        continue

                    next_cell = ws.cell(row=row_num, column=col_index + 1)
                    prev_cell = ws.cell(row=row_num, column=col_index - 1)
                    gaussia_values.append(target_cell.value)

                    if (target_cell.value is None
                            and next_cell.value is not None
                            and prev_cell.value is not None):
                        #print("This is the dividing none")
                        break

                mice = group_numbers(gaussia_values)
                for designation, values in mice.items():
                    try:
                        value1, value2, value3 = values
                    except ValueError:
                        print(f"Skipping {designation}: expected 3 values, got {values}")
                        continue
                    else:
                        rows.append({
                            'model': model_id,
                            'passage': passage,
                            'date': input_date,
                            'designation': designation,
                            'value1': value1,
                            'value2': value2,
                            'value3': value3,
                        })

                gaussia_values = []
        print("Sheet finished")        
        #break  # stop after first datetime found in this sheet
# Out:
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished
# Row 10 has no numeric values in first 9 columns, skipping
# Sheet finished

# %%
df = pd.DataFrame(rows, columns=['model', 'passage', 'date', 'designation', 'value1', 'value2', 'value3'])

# %%
df_date = df[(df['date'] == '2026-07-15') & (df['model'] == '723')]
df_date.head()
# Out:
#     model passage       date designation  value1  value2  value3
# 212   723       0 2026-07-15           B    2870    2930    2765
# 213   723       0 2026-07-15           C  629355  594545  561665

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 668 entries, 0 to 667
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   model        668 non-null    str
#  1   passage      668 non-null    str
#  2   date         668 non-null    datetime64[us]
#  3   designation  668 non-null    str
#  4   value1       668 non-null    int64
#  5   value2       668 non-null    int64
#  6   value3       668 non-null    int64
# dtypes: datetime64[us](1), int64(3), str(3)
# memory usage: 39.9 KB

# %%
df_date = df[(df['model'] == '723')]
df_date.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 157 to 216
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   model        60 non-null     str
#  1   passage      60 non-null     str
#  2   date         60 non-null     datetime64[us]
#  3   designation  60 non-null     str
#  4   value1       60 non-null     int64
#  5   value2       60 non-null     int64
#  6   value3       60 non-null     int64
# dtypes: datetime64[us](1), int64(3), str(3)
# memory usage: 3.7 KB

# %%
df = pd.DataFrame(rows, columns=['model', 'passage', 'date', 'designation', 'value1', 'value2', 'value3'])

# %%
df.head(20)
# Out:
#    model passage       date designation  value1  value2  value3
# 0    715       0 2025-12-10           A    2330    2735    2420
# 1    715       0 2025-12-10           B    1870    2210    2280
# 2    715       0 2025-12-10           C    2305    2880    2645
# 3    715       0 2025-12-17           A    1785    1885    2345
# 4    715       0 2025-12-17           B    1575    2005    1970
# 5    715       0 2025-12-17           C    2195    1930    2425
# 6    715       0 2025-12-31           A    2335    2300    2920
# 7    715       0 2025-12-31           B    1990    2380    2315
# 8    715       0 2025-12-31           C   15400   17660   17460
# 9    715       0 2026-01-07           A    2500    2490    2710
# 10   715       0 2026-01-07           B    3250    4215    3460
# 11   715       0 2026-01-07           C   34860   37480   35820
# 12   715       0 2026-01-21           A    3855    4920    5075
# 13   715       0 2026-01-21           B   10625   10815   10955
# 14   715       0 2026-01-21           C  213010  229110  249375
# 15   715       0 2026-01-28           A    9950    8850    9525
# 16   715       0 2026-01-28           B   26720   26985   27160
# 17   715       0 2026-01-28           C  508555  517075  537340
# 18   715       0 2026-02-04           A    3200    2595    3790
# 19   715       0 2026-02-04           B    8445    9025   10790

# %%
def drop_non_numerics(lst):
    result = []
    for x in lst:
        if isinstance(x, bool):
            continue
        if isinstance(x, (int, float)):
            result.append(x)
        elif isinstance(x, str):
            try:
                result.append(float(x) if '.' in x else int(x))
            except ValueError:
                pass
    return result

# %%
"""
QC pass for sgluc Excel files, meant to run BEFORE gaussia_values ingestion.

Strategy: skip + log. Nothing here modifies source files. Any sheet with a
flagged issue is left out of the "clean" list and written to the report,
so it can be fixed by hand in Excel and re-checked.

Checks:
- Sheet title parses into model_id/passage
- Every date row (col B) has a dividing None found via the same forward
  scan the ingestion script uses. A single row missing its divider isn't
  flagged; more than one missing divider in a sheet is treated as a
  real pattern and gets flagged.
- Value count before the divider is a clean multiple of 3 (triplets)

Assumes the same helper functions used in the ingestion script
(get_model_number, get_passage_number, load_workbooks) are importable
from your existing utils module — swap the import below to match.
"""

from datetime import datetime
import logging
from pathlib import Path

# from your_utils_module import load_workbooks, get_model_number, get_passage_number

logging.basicConfig(
    filename='qc_report.log',
    filemode='w',
    level=logging.INFO,
    format='%(asctime)s | %(levelname)s | %(message)s'
)

DATA_START_COL = 3  # column C — first real-data column, matches ingestion script


def find_date_rows(ws):
    """Return list of row numbers in column B that hold a real datetime."""
    return [cell.row for cell in ws["B"] if isinstance(cell.value, datetime)]


def check_title_parses(ws_title):
    """Try the same title parsing the ingestion script relies on."""
    try:
        model_id = get_model_number(ws_title)
        passage = get_passage_number(ws_title)
        if model_id is None or passage is None:
            return None, None, f"Title '{ws_title}' parsed but returned None"
        return model_id, passage, None
    except Exception as e:
        return None, None, f"Title '{ws_title}' failed to parse: {e}"


def scan_row(ws, row_num):
    """
    Replicates the ingestion script's forward scan from column C, looking
    for the "dividing None" (a None flanked by non-None cells on both
    sides). Returns (has_divider, values) where values are the real
    values collected before the divider (or before running off the end
    of the row, if no divider was found).
    """
    values = []
    has_divider = False
    for col_index in range(DATA_START_COL, ws.max_column + 1):
        target_cell = ws.cell(row=row_num, column=col_index)
        next_cell = ws.cell(row=row_num, column=col_index + 1)
        prev_cell = ws.cell(row=row_num, column=col_index - 1)
        if (target_cell.value is None
                and next_cell.value is not None
                and prev_cell.value is not None):
            has_divider = True
            break
        if(target_cell.value is None and next_cell.value is None):  #Checks if the next cells are empty
            n = 0
            found_non_empty = False
            while n < 9 and (col_index + n) <= ws.max_column:
                s_cell = ws.cell(row=row_num, column=col_index + n)
                if s_cell.value is not None:
                    found_non_empty = True
                    break
                n += 1
            if found_non_empty:
                continue
            has_divider = True
            break
        values.append(target_cell.value)
    return has_divider, values


def check_dividers_and_triplets(ws, date_rows):
    """
    For each date row, check whether a dividing None was found at all, and
    whether the values collected before it are a clean multiple of 3
    (group_numbers expects triplets).

    A single date row missing its divider isn't flagged on its own — but
    if MORE THAN ONE date row in the sheet is missing a divider, that's
    a pattern worth flagging rather than a one-off.
    """
    issues = []
    missing_divider_rows = []
    
    for row_num in date_rows:
        has_divider, values = scan_row(ws, row_num)
        #Have to drop all non-numeric values from values
        values = drop_non_numerics(values)
        
        if not has_divider:
            missing_divider_rows.append(row_num)
            continue
        if len(values) % 3 != 0:
            issues.append(
                f"Row {row_num}: {len(values)} data columns found before dividing gap, "
                f"not divisible by 3 (check for a missing/extra replicate or stray value)"
            )

    if len(missing_divider_rows) > 1:
        issues.append(
            f"{len(missing_divider_rows)} date row(s) with no dividing None found: "
            f"rows {missing_divider_rows}"
        )

    return issues


def qc_check_workbook(item):
    filename = item['filename']
    wb = item['workbook']
    result = {'filename': filename, 'clean_sheets': [], 'flagged_sheets': []}

    for sheet_name in wb.sheetnames:
        ws = wb[sheet_name]
        issues = []

        model_id, passage, title_err = check_title_parses(ws.title)
        if title_err:
            issues.append(title_err)

        date_rows = find_date_rows(ws)
        if not date_rows:
            issues.append("No datetime found in column B")
        else:
            issues.extend(check_dividers_and_triplets(ws, date_rows))

        if issues:
            for issue in issues:
                logging.warning(f"{filename} | {sheet_name} | {issue}")
            result['flagged_sheets'].append({'sheet': sheet_name, 'issues': issues})
        else:
            result['clean_sheets'].append(sheet_name)

    return result

# %%
def run_qc(source_dir='./sgluc_files'):
    workbooks = load_workbooks(source_dir)
    all_results = [qc_check_workbook(item) for item in workbooks]

    total_flagged = sum(len(r['flagged_sheets']) for r in all_results)
    total_clean = sum(len(r['clean_sheets']) for r in all_results)

    print(f"QC complete: {total_clean} sheet(s) clean, {total_flagged} sheet(s) flagged.")
    if total_flagged:
        print("\nFlagged sheets:")
        for r in all_results:
            for flagged in r['flagged_sheets']:
                print(f"\n  {r['filename']} | {flagged['sheet']}")
                for issue in flagged['issues']:
                    print(f"    - {issue}")

    return all_results


if __name__ == '__main__':
    run_qc()
# Out:
# QC complete: 154 sheet(s) clean, 194 sheet(s) flagged.
#
# Flagged sheets:
#
#   GS500-sGluc_COMPLETE.xlsx | GS500
#     - Title 'GS500' failed to parse: String 'GS500' doesn't match expected GBX###P# format
#
#   GS500-sGluc_COMPLETE.xlsx | GBX1500
#     - Title 'GBX1500' failed to parse: String 'GBX1500' doesn't match expected GBX###P# format
#
#   GS501-sGluc.xlsx | GS501
#     - Title 'GS501' failed to parse: String 'GS501' doesn't match expected GBX###P# format
#
#   GS501-sGluc.xlsx | GBX1501
#     - Title 'GBX1501' failed to parse: String 'GBX1501' doesn't match expected GBX###P# format
#
#   GS501-sGluc.xlsx | GBX2501
#     - Title 'GBX2501' failed to parse: String 'GBX2501' doesn't match expected GBX###P# format
#
#   GS501-sGluc.xlsx | GBX3501
#     - Title 'GBX3501' failed to parse: String 'GBX3501' doesn't match expected GBX###P# format
#
#   GS501-sGluc.xlsx | GBX4501
#     - Title 'GBX4501' failed to parse: String 'GBX4501' doesn't match expected GBX###P# format
#
#   GS502-sGluc_COMPLETE.xlsx | GS502
#     - Title 'GS502' failed to parse: String 'GS502' doesn't match expected GBX###P# format
#
#   GS502-sGluc_COMPLETE.xlsx | GBX1502
#     - Title 'GBX1502' failed to parse: String 'GBX1502' doesn't match expected GBX###P# format
#
#   GS502-sGluc_COMPLETE.xlsx | GBX2502
#     - Title 'GBX2502' failed to parse: String 'GBX2502' doesn't match expected GBX###P# format
#
#   GS504-sGluc.xlsx | GS504
#     - Title 'GS504' failed to parse: String 'GS504' doesn't match expected GBX###P# format
#
#   GS504-sGluc.xlsx | GBX1504
#     - Title 'GBX1504' failed to parse: String 'GBX1504' doesn't match expected GBX###P# format
#
#   GS504-sGluc.xlsx | GBX2504
#     - Title 'GBX2504' failed to parse: String 'GBX2504' doesn't match expected GBX###P# format
#
#   GS504-sGluc.xlsx | GBX3504
#     - Title 'GBX3504' failed to parse: String 'GBX3504' doesn't match expected GBX###P# format
#
#   GS504-sGluc.xlsx | GBX4504
#     - Title 'GBX4504' failed to parse: String 'GBX4504' doesn't match expected GBX###P# format
#
#   GS506-sGluc.xlsx | GS506
#     - Title 'GS506' failed to parse: String 'GS506' doesn't match expected GBX###P# format
#     - Row 13: 2 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS506-sGluc.xlsx | GBX1506
#     - Title 'GBX1506' failed to parse: String 'GBX1506' doesn't match expected GBX###P# format
#
#   GS506-sGluc.xlsx | GBX2506
#     - Title 'GBX2506' failed to parse: String 'GBX2506' doesn't match expected GBX###P# format
#
#   GS506-sGluc.xlsx | GBX3506
#     - Title 'GBX3506' failed to parse: String 'GBX3506' doesn't match expected GBX###P# format
#
#   GS506-sGluc.xlsx | GBX4506
#     - Title 'GBX4506' failed to parse: String 'GBX4506' doesn't match expected GBX###P# format
#
#   GS506-sGluc.xlsx | GBX5506
#     - Title 'GBX5506' failed to parse: String 'GBX5506' doesn't match expected GBX###P# format
#     - Row 19: 5 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS509-sGluc_ENDED.xlsx | GS509
#     - Title 'GS509' failed to parse: String 'GS509' doesn't match expected GBX###P# format
#
#   GS510-sGluc.xlsx | GS510
#     - Title 'GS510' failed to parse: String 'GS510' doesn't match expected GBX###P# format
#
#   GS510-sGluc.xlsx | GBX1510
#     - Title 'GBX1510' failed to parse: String 'GBX1510' doesn't match expected GBX###P# format
#
#   GS510-sGluc.xlsx | GBX2510
#     - Title 'GBX2510' failed to parse: String 'GBX2510' doesn't match expected GBX###P# format
#
#   GS510-sGluc.xlsx | GBX3510
#     - Title 'GBX3510' failed to parse: String 'GBX3510' doesn't match expected GBX###P# format
#
#   GS510-sGluc.xlsx | GS4510
#     - Title 'GS4510 ' failed to parse: String 'GS4510 ' doesn't match expected GBX###P# format
#
#   GS511-sGluc_ENDED.xlsx | GS511
#     - Title 'GS511' failed to parse: String 'GS511' doesn't match expected GBX###P# format
#     - Row 26: 2 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS511-sGluc_ENDED.xlsx | GBX1511
#     - Title 'GBX1511' failed to parse: String 'GBX1511' doesn't match expected GBX###P# format
#
#   GS512-sGluc.xlsx | GS512
#     - Title 'GS512' failed to parse: String 'GS512' doesn't match expected GBX###P# format
#
#   GS512-sGluc.xlsx | GBX1512
#     - Title 'GBX1512' failed to parse: String 'GBX1512' doesn't match expected GBX###P# format
#
#   GS512-sGluc.xlsx | GBX2512
#     - Title 'GBX2512' failed to parse: String 'GBX2512' doesn't match expected GBX###P# format
#
#   GS512-sGluc.xlsx | GBX3512
#     - Title 'GBX3512' failed to parse: String 'GBX3512' doesn't match expected GBX###P# format
#
#   GS512-sGluc.xlsx | GBX4512
#     - Title 'GBX4512' failed to parse: String 'GBX4512' doesn't match expected GBX###P# format
#     - Row 12: 5 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS514-sGluc_COMPLETE.xlsx | GS514
#     - Title 'GS514' failed to parse: String 'GS514' doesn't match expected GBX###P# format
#
#   GS515-sGluc.xlsx | GS515
#     - Title 'GS515' failed to parse: String 'GS515' doesn't match expected GBX###P# format
#
#   GS515-sGluc.xlsx | GBX1515
#     - Title 'GBX1515' failed to parse: String 'GBX1515' doesn't match expected GBX###P# format
#
#   GS515-sGluc.xlsx | GBX2515
#     - Title 'GBX2515' failed to parse: String 'GBX2515' doesn't match expected GBX###P# format
#
#   GS515-sGluc.xlsx | GBX3515
#     - Title 'GBX3515' failed to parse: String 'GBX3515' doesn't match expected GBX###P# format
#
#   GS515-sGluc.xlsx | GBX4515
#     - Title 'GBX4515' failed to parse: String 'GBX4515' doesn't match expected GBX###P# format
#
#   GS517-sGluc.xlsx | GS517
#     - Title 'GS517' failed to parse: String 'GS517' doesn't match expected GBX###P# format
#
#   GS517-sGluc.xlsx | GBX1517 (2)
#     - Title 'GBX1517 (2)' failed to parse: String 'GBX1517 (2)' doesn't match expected GBX###P# format
#
#   GS517-sGluc.xlsx | GBX1517
#     - Title 'GBX1517' failed to parse: String 'GBX1517' doesn't match expected GBX###P# format
#
#   GS517-sGluc.xlsx | GBX2517
#     - Title 'GBX2517' failed to parse: String 'GBX2517' doesn't match expected GBX###P# format
#
#   GS518-sGluc.xlsx | GS518
#     - Title 'GS518' failed to parse: String 'GS518' doesn't match expected GBX###P# format
#
#   GS518-sGluc.xlsx | GBX1518
#     - Title 'GBX1518' failed to parse: String 'GBX1518' doesn't match expected GBX###P# format
#
#   GS519-sGluc.xlsx | GS519
#     - Title 'GS519' failed to parse: String 'GS519' doesn't match expected GBX###P# format
#     - Row 18: 2 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#     - Row 19: 2 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS519-sGluc.xlsx |  GBX1519
#     - Title ' GBX1519' failed to parse: String ' GBX1519' doesn't match expected GBX###P# format
#
#   GS520-sGluc_RE.RE-INJ.xlsx | GS520
#     - Title 'GS520' failed to parse: String 'GS520' doesn't match expected GBX###P# format
#
#   GS520-sGluc_RE.RE-INJ.xlsx | GBX1520
#     - Title 'GBX1520' failed to parse: String 'GBX1520' doesn't match expected GBX###P# format
#
#   GS520-sGluc_RE.RE-INJ.xlsx | GBX2520
#     - Title 'GBX2520' failed to parse: String 'GBX2520' doesn't match expected GBX###P# format
#
#   GS520-sGluc_RE.RE-INJ.xlsx | GBX3520
#     - Title 'GBX3520' failed to parse: String 'GBX3520' doesn't match expected GBX###P# format
#
#   GS520-sGluc_RE.RE-INJ.xlsx | GS520P4
#     - Title 'GS520P4' failed to parse: String 'GS520P4' doesn't match expected GBX###P# format
#
#   GS520-sGluc_RE.RE-INJ.xlsx | GS520P5
#     - Title 'GS520P5' failed to parse: String 'GS520P5' doesn't match expected GBX###P# format
#
#   GS522-sGluc.xlsx | GS522
#     - Title 'GS522' failed to parse: String 'GS522' doesn't match expected GBX###P# format
#
#   GS522-sGluc.xlsx | GBX1522_2
#     - Title 'GBX1522_2' failed to parse: String 'GBX1522_2' doesn't match expected GBX###P# format
#     - Row 38: 2 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS523-sGluc.xlsx | GS523
#     - Title 'GS523' failed to parse: String 'GS523' doesn't match expected GBX###P# format
#
#   GS523-sGluc.xlsx | GBX1523
#     - Title 'GBX1523' failed to parse: String 'GBX1523' doesn't match expected GBX###P# format
#
#   GS523-sGluc.xlsx | GBX2523
#     - Title 'GBX2523' failed to parse: String 'GBX2523' doesn't match expected GBX###P# format
#
#   GS527-sGluc.xlsx | GS527
#     - Title 'GS527' failed to parse: String 'GS527' doesn't match expected GBX###P# format
#
#   GS528-sGluc.xlsx | GS528
#     - Title 'GS528' failed to parse: String 'GS528' doesn't match expected GBX###P# format
#
#   GS528-sGluc.xlsx | GBX1528
#     - Title 'GBX1528' failed to parse: String 'GBX1528' doesn't match expected GBX###P# format
#
#   GS528-sGluc.xlsx | GBX2528
#     - Title 'GBX2528' failed to parse: String 'GBX2528' doesn't match expected GBX###P# format
#
#   GS530-sGluc_ENDED.xlsx | GS530
#     - Title 'GS530' failed to parse: String 'GS530' doesn't match expected GBX###P# format
#     - Row 16: 8 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS531-sGluc.xlsx | GS531
#     - Title 'GS531' failed to parse: String 'GS531' doesn't match expected GBX###P# format
#
#   GS533-sGluc_ENDED.xlsx | GS533
#     - Title 'GS533' failed to parse: String 'GS533' doesn't match expected GBX###P# format
#
#   GS533-sGluc_ENDED.xlsx | GBX1533
#     - Title 'GBX1533' failed to parse: String 'GBX1533' doesn't match expected GBX###P# format
#
#   GS534-sGluc_ENDED.xlsx | GS534
#     - Title 'GS534' failed to parse: String 'GS534' doesn't match expected GBX###P# format
#
#   GS534-sGluc_ENDED.xlsx | GS1534
#     - Title 'GS1534' failed to parse: String 'GS1534' doesn't match expected GBX###P# format
#
#   GS536-sGluc.xlsx | GS536
#     - Title 'GS536' failed to parse: String 'GS536' doesn't match expected GBX###P# format
#
#   GS536-sGluc.xlsx | GBX1536
#     - Title 'GBX1536' failed to parse: String 'GBX1536' doesn't match expected GBX###P# format
#
#   GS536-sGluc.xlsx | GBX2536
#     - Title 'GBX2536' failed to parse: String 'GBX2536' doesn't match expected GBX###P# format
#
#   GS536-sGluc.xlsx | GBX3536
#     - Title 'GBX3536' failed to parse: String 'GBX3536' doesn't match expected GBX###P# format
#
#   GS536-sGluc.xlsx | GBX4536
#     - Title 'GBX4536' failed to parse: String 'GBX4536' doesn't match expected GBX###P# format
#
#   GS536-sGluc.xlsx | GBX5536
#     - Title 'GBX5536' failed to parse: String 'GBX5536' doesn't match expected GBX###P# format
#
#   GS536-sGluc.xlsx | GBX6536
#     - Title 'GBX6536' failed to parse: String 'GBX6536' doesn't match expected GBX###P# format
#
#   GS537-sGluc_ENDED.xlsx | GS537
#     - Title 'GS537' failed to parse: String 'GS537' doesn't match expected GBX###P# format
#
#   GS537-sGluc_ENDED.xlsx | GBX1537
#     - Title 'GBX1537' failed to parse: String 'GBX1537' doesn't match expected GBX###P# format
#
#   GS539-sGluc_COMPLETE.xlsx | GS539
#     - Title 'GS539' failed to parse: String 'GS539' doesn't match expected GBX###P# format
#
#   GS539-sGluc_COMPLETE.xlsx | GBX1539
#     - Title 'GBX1539' failed to parse: String 'GBX1539' doesn't match expected GBX###P# format
#
#   GS539-sGluc_COMPLETE.xlsx | GBX2539
#     - Title 'GBX2539' failed to parse: String 'GBX2539' doesn't match expected GBX###P# format
#
#   GS542-sGluc_ENDED.xlsx | GS542
#     - Title 'GS542' failed to parse: String 'GS542' doesn't match expected GBX###P# format
#
#   GS544-sGluc.xlsx | GS544
#     - Title 'GS544' failed to parse: String 'GS544' doesn't match expected GBX###P# format
#     - Row 37: 2 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS544-sGluc.xlsx | GS1544
#     - Title 'GS1544' failed to parse: String 'GS1544' doesn't match expected GBX###P# format
#     - Row 12: 2 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS546-sGluc.xlsx | GS546
#     - Title 'GS546' failed to parse: String 'GS546' doesn't match expected GBX###P# format
#
#   GS546-sGluc.xlsx | GBX1546
#     - Title 'GBX1546' failed to parse: String 'GBX1546' doesn't match expected GBX###P# format
#
#   GS546-sGluc.xlsx | GBX2546
#     - Title 'GBX2546' failed to parse: String 'GBX2546' doesn't match expected GBX###P# format
#
#   GS546-sGluc.xlsx | GBX3546
#     - Title 'GBX3546' failed to parse: String 'GBX3546' doesn't match expected GBX###P# format
#
#   GS546-sGluc.xlsx | GBX4546
#     - Title 'GBX4546' failed to parse: String 'GBX4546' doesn't match expected GBX###P# format
#
#   GS547-sGluc.xlsx | GS547
#     - Title 'GS547' failed to parse: String 'GS547' doesn't match expected GBX###P# format
#
#   GS547-sGluc.xlsx | GBX1547 (Electro)
#     - Title 'GBX1547 (Electro)' failed to parse: String 'GBX1547 (Electro)' doesn't match expected GBX###P# format
#
#   GS547-sGluc.xlsx | GBX2547 (Electro)
#     - Title 'GBX2547 (Electro)' failed to parse: String 'GBX2547 (Electro)' doesn't match expected GBX###P# format
#
#   GS547-sGluc.xlsx | GBX1547 (LV)
#     - Title 'GBX1547 (LV)' failed to parse: String 'GBX1547 (LV)' doesn't match expected GBX###P# format
#
#   GS547-sGluc.xlsx | GBX2547 (LV)
#     - Title 'GBX2547 (LV)' failed to parse: String 'GBX2547 (LV)' doesn't match expected GBX###P# format
#
#   GS547-sGluc.xlsx | GBX3547 (LV)
#     - Title 'GBX3547 (LV)' failed to parse: String 'GBX3547 (LV)' doesn't match expected GBX###P# format
#
#   GS548-sGluc.xlsx | GS548-EL
#     - Title 'GS548-EL' failed to parse: String 'GS548-EL' doesn't match expected GBX###P# format
#
#   GS548-sGluc.xlsx | GBX1548-EL
#     - Title 'GBX1548-EL' failed to parse: String 'GBX1548-EL' doesn't match expected GBX###P# format
#
#   GS548-sGluc.xlsx | GBX1548-EL (2)
#     - Title 'GBX1548-EL (2)' failed to parse: String 'GBX1548-EL (2)' doesn't match expected GBX###P# format
#
#   GS548-sGluc.xlsx | GBX2548-EL
#     - Title 'GBX2548-EL' failed to parse: String 'GBX2548-EL' doesn't match expected GBX###P# format
#
#   GS548-sGluc.xlsx | GS548-LV
#     - Title 'GS548-LV' failed to parse: String 'GS548-LV' doesn't match expected GBX###P# format
#
#   GS548-sGluc.xlsx | GBX1548-LV
#     - Title 'GBX1548-LV' failed to parse: String 'GBX1548-LV' doesn't match expected GBX###P# format
#
#   GS548-sGluc.xlsx | GBX1548-LV (2)
#     - Title 'GBX1548-LV (2)' failed to parse: String 'GBX1548-LV (2)' doesn't match expected GBX###P# format
#
#   GS549-sGluc_COMPLETE.xlsx | GS549
#     - Title 'GS549' failed to parse: String 'GS549' doesn't match expected GBX###P# format
#
#   GS550-sGluc_COMPLETE.xlsx | GS550
#     - Title 'GS550' failed to parse: String 'GS550' doesn't match expected GBX###P# format
#
#   GS550-sGluc_COMPLETE.xlsx | GBX1550
#     - Title 'GBX1550' failed to parse: String 'GBX1550' doesn't match expected GBX###P# format
#     - Row 12: 2 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS551-sGluc.xlsx | GS551
#     - Title 'GS551' failed to parse: String 'GS551' doesn't match expected GBX###P# format
#
#   GS551-sGluc.xlsx | GBX1551
#     - Title 'GBX1551' failed to parse: String 'GBX1551' doesn't match expected GBX###P# format
#
#   GS551-sGluc.xlsx | GBX2551
#     - Title 'GBX2551' failed to parse: String 'GBX2551' doesn't match expected GBX###P# format
#
#   GS551-sGluc.xlsx | GBX3551
#     - Title 'GBX3551' failed to parse: String 'GBX3551' doesn't match expected GBX###P# format
#
#   GS551-sGluc.xlsx | GBX4551
#     - Title 'GBX4551' failed to parse: String 'GBX4551' doesn't match expected GBX###P# format
#
#   GS554-sGluc.xlsx | GS554
#     - Title 'GS554' failed to parse: String 'GS554' doesn't match expected GBX###P# format
#
#   GS554-sGluc.xlsx | GBX1554
#     - Title 'GBX1554' failed to parse: String 'GBX1554' doesn't match expected GBX###P# format
#
#   GS554-sGluc.xlsx | GBX2554
#     - Title 'GBX2554' failed to parse: String 'GBX2554' doesn't match expected GBX###P# format
#
#   GS554-sGluc.xlsx | GBX3554
#     - Title 'GBX3554' failed to parse: String 'GBX3554' doesn't match expected GBX###P# format
#
#   GS554-sGluc.xlsx | GBX4554
#     - Title 'GBX4554' failed to parse: String 'GBX4554' doesn't match expected GBX###P# format
#
#   GS554-sGluc.xlsx | GBX5554
#     - Title 'GBX5554' failed to parse: String 'GBX5554' doesn't match expected GBX###P# format
#
#   GS554-sGluc.xlsx | GBX6554
#     - Title 'GBX6554' failed to parse: String 'GBX6554' doesn't match expected GBX###P# format
#
#   GS554-sGluc.xlsx | GBX7554
#     - Title 'GBX7554' failed to parse: String 'GBX7554' doesn't match expected GBX###P# format
#
#   GS554-sGluc.xlsx | GBX8554
#     - Title 'GBX8554' failed to parse: String 'GBX8554' doesn't match expected GBX###P# format
#
#   GS557-sGluc_ENDED.xlsx | GS557
#     - Title 'GS557' failed to parse: String 'GS557' doesn't match expected GBX###P# format
#
#   GS557-sGluc_ENDED.xlsx | GS1557
#     - Title 'GS1557' failed to parse: String 'GS1557' doesn't match expected GBX###P# format
#
#   GS558-sGluc.xlsx | GS558
#     - Title 'GS558' failed to parse: String 'GS558' doesn't match expected GBX###P# format
#
#   GS559-sGluc_COMPLETE.xlsx | GS559
#     - Title 'GS559' failed to parse: String 'GS559' doesn't match expected GBX###P# format
#
#   GS559-sGluc_COMPLETE.xlsx | GBX1559
#     - Title 'GBX1559' failed to parse: String 'GBX1559' doesn't match expected GBX###P# format
#
#   GS565-sGluc_ENDED.xlsx | GS565
#     - Title 'GS565' failed to parse: String 'GS565' doesn't match expected GBX###P# format
#
#   GS565-sGluc_ENDED.xlsx | GBX1565
#     - Title 'GBX1565' failed to parse: String 'GBX1565' doesn't match expected GBX###P# format
#
#   GS565-sGluc_ENDED.xlsx | GBX2565
#     - Title 'GBX2565' failed to parse: String 'GBX2565' doesn't match expected GBX###P# format
#
#   GS569-sGluc.xlsx | GS569
#     - Title 'GS569' failed to parse: String 'GS569' doesn't match expected GBX###P# format
#
#   GS569-sGluc.xlsx | GBX1569
#     - Title 'GBX1569' failed to parse: String 'GBX1569' doesn't match expected GBX###P# format
#
#   GS569-sGluc.xlsx | GBX1569_2
#     - Title 'GBX1569_2' failed to parse: String 'GBX1569_2' doesn't match expected GBX###P# format
#     - Row 10: 5 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS569-sGluc.xlsx | GBX2569
#     - Title 'GBX2569' failed to parse: String 'GBX2569' doesn't match expected GBX###P# format
#
#   GS569-sGluc.xlsx | GBX3569
#     - Title 'GBX3569' failed to parse: String 'GBX3569' doesn't match expected GBX###P# format
#
#   GS569-sGluc.xlsx | GBX4569
#     - Title 'GBX4569' failed to parse: String 'GBX4569' doesn't match expected GBX###P# format
#
#   GS570-sGluc.xlsx | GS570
#     - Title 'GS570' failed to parse: String 'GS570' doesn't match expected GBX###P# format
#
#   GS570-sGluc.xlsx | GBX1570
#     - Title 'GBX1570' failed to parse: String 'GBX1570' doesn't match expected GBX###P# format
#
#   GS570-sGluc.xlsx | GBX2570
#     - Title 'GBX2570' failed to parse: String 'GBX2570' doesn't match expected GBX###P# format
#
#   GS570-sGluc.xlsx | GBX3570
#     - Title 'GBX3570' failed to parse: String 'GBX3570' doesn't match expected GBX###P# format
#
#   GS570-sGluc.xlsx | GBX4570
#     - Title 'GBX4570' failed to parse: String 'GBX4570' doesn't match expected GBX###P# format
#
#   GS570-sGluc.xlsx | GBX5570
#     - Title 'GBX5570' failed to parse: String 'GBX5570' doesn't match expected GBX###P# format
#
#   GS571-sGluc_ENDED.xlsx | GS571
#     - Title 'GS571' failed to parse: String 'GS571' doesn't match expected GBX###P# format
#
#   GS572-sGluc.xlsx | GS572
#     - Title 'GS572' failed to parse: String 'GS572' doesn't match expected GBX###P# format
#
#   GS572-sGluc.xlsx | GBX1572
#     - Title 'GBX1572' failed to parse: String 'GBX1572' doesn't match expected GBX###P# format
#
#   GS572-sGluc.xlsx | GBX2572
#     - Title 'GBX2572' failed to parse: String 'GBX2572' doesn't match expected GBX###P# format
#
#   GS572-sGluc.xlsx | GBX3572
#     - Title 'GBX3572' failed to parse: String 'GBX3572' doesn't match expected GBX###P# format
#
#   GS574-sGluc.xlsx | GS574
#     - Title 'GS574' failed to parse: String 'GS574' doesn't match expected GBX###P# format
#
#   GS574-sGluc.xlsx | GBX1574
#     - Title 'GBX1574' failed to parse: String 'GBX1574' doesn't match expected GBX###P# format
#
#   GS574-sGluc.xlsx | GBX2574
#     - Title 'GBX2574' failed to parse: String 'GBX2574' doesn't match expected GBX###P# format
#
#   GS575-sGluc.xlsx | GS575 (2)
#     - Title 'GS575 (2)' failed to parse: String 'GS575 (2)' doesn't match expected GBX###P# format
#
#   GS575-sGluc.xlsx | GBX1575
#     - Title 'GBX1575' failed to parse: String 'GBX1575' doesn't match expected GBX###P# format
#
#   GS576-sGluc.xlsx | GS576
#     - Title 'GS576' failed to parse: String 'GS576' doesn't match expected GBX###P# format
#
#   GS576-sGluc.xlsx | GBX1576
#     - Title 'GBX1576' failed to parse: String 'GBX1576' doesn't match expected GBX###P# format
#
#   GS576-sGluc.xlsx | GBX2576
#     - Title 'GBX2576' failed to parse: String 'GBX2576' doesn't match expected GBX###P# format
#
#   GS577-sGluc.xlsx | GS577
#     - Title 'GS577' failed to parse: String 'GS577' doesn't match expected GBX###P# format
#
#   GS577-sGluc.xlsx | GBX1577
#     - Title 'GBX1577' failed to parse: String 'GBX1577' doesn't match expected GBX###P# format
#
#   GS578-sGluc.xlsx | GS578
#     - Title 'GS578' failed to parse: String 'GS578' doesn't match expected GBX###P# format
#     - Row 27: 14 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS578-sGluc.xlsx | GS1578
#     - Title 'GS1578' failed to parse: String 'GS1578' doesn't match expected GBX###P# format
#
#   GS579-sGluc_.xlsx | GS579
#     - Title 'GS579' failed to parse: String 'GS579' doesn't match expected GBX###P# format
#
#   GS579-sGluc_.xlsx | GBX1579
#     - Title 'GBX1579' failed to parse: String 'GBX1579' doesn't match expected GBX###P# format
#
#   GS580-sGluc_COMPLETE.xlsx | GS580
#     - Title 'GS580' failed to parse: String 'GS580' doesn't match expected GBX###P# format
#
#   GS580-sGluc_COMPLETE.xlsx | GBX1580
#     - Title 'GBX1580' failed to parse: String 'GBX1580' doesn't match expected GBX###P# format
#
#   GS580-sGluc_COMPLETE.xlsx | GBX2580
#     - Title 'GBX2580' failed to parse: String 'GBX2580' doesn't match expected GBX###P# format
#
#   GS580-sGluc_COMPLETE.xlsx | GBX3580
#     - Title 'GBX3580' failed to parse: String 'GBX3580' doesn't match expected GBX###P# format
#
#   GS580-sGluc_COMPLETE.xlsx | GBX4580
#     - Title 'GBX4580' failed to parse: String 'GBX4580' doesn't match expected GBX###P# format
#     - Row 13: 2 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS581-sGluc_ENDED.xlsx | GS581
#     - Title 'GS581' failed to parse: String 'GS581' doesn't match expected GBX###P# format
#
#   GS585-sGluc_REQ.RE-INJ.xlsx | GS585
#     - Title 'GS585' failed to parse: String 'GS585' doesn't match expected GBX###P# format
#
#   GS587-sGluc_ENDED.xlsx | GS587
#     - Title 'GS587' failed to parse: String 'GS587' doesn't match expected GBX###P# format
#
#   GS589-sGluc_REQ.RE-INJ.xlsx | GS589
#     - Title 'GS589' failed to parse: String 'GS589' doesn't match expected GBX###P# format
#
#   GS589-sGluc_REQ.RE-INJ.xlsx | GS1589
#     - Title 'GS1589' failed to parse: String 'GS1589' doesn't match expected GBX###P# format
#
#   GS590-sGluc_COMPLETE.xlsx | GS590
#     - Title 'GS590' failed to parse: String 'GS590' doesn't match expected GBX###P# format
#
#   GS590-sGluc_COMPLETE.xlsx | GS1590
#     - Title 'GS1590' failed to parse: String 'GS1590' doesn't match expected GBX###P# format
#
#   GS593-sGluc_COMPLETE.xlsx | GS593
#     - Title 'GS593' failed to parse: String 'GS593' doesn't match expected GBX###P# format
#
#   GS593-sGluc_COMPLETE.xlsx | GBX1593
#     - Title 'GBX1593' failed to parse: String 'GBX1593' doesn't match expected GBX###P# format
#
#   GS593-sGluc_COMPLETE.xlsx | GBX1593 (2)
#     - Title 'GBX1593 (2)' failed to parse: String 'GBX1593 (2)' doesn't match expected GBX###P# format
#
#   GS594-sGluc_COMPLETE.xlsx | GS594
#     - Title 'GS594' failed to parse: String 'GS594' doesn't match expected GBX###P# format
#
#   GS594-sGluc_COMPLETE.xlsx | GS1594
#     - Title 'GS1594' failed to parse: String 'GS1594' doesn't match expected GBX###P# format
#
#   GS599-sGluc_ENDED.xlsx | GS599
#     - Title 'GS599' failed to parse: String 'GS599' doesn't match expected GBX###P# format
#
#   GS600-sGluc.xlsx | GS600
#     - Title 'GS600' failed to parse: String 'GS600' doesn't match expected GBX###P# format
#
#   GS601-sGluc_REQ.RE-INJ.xlsx | GS601
#     - Title 'GS601' failed to parse: String 'GS601' doesn't match expected GBX###P# format
#
#   GS601-sGluc_REQ.RE-INJ.xlsx | GS601P1
#     - Title 'GS601P1' failed to parse: String 'GS601P1' doesn't match expected GBX###P# format
#     - Row 10: 5 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS602-sGluc_COMPLETE.xlsx | GS602
#     - Title 'GS602' failed to parse: String 'GS602' doesn't match expected GBX###P# format
#
#   GS603-sGluc.xlsx | transpose
#     - Title 'transpose' failed to parse: String 'transpose' doesn't match expected GBX###P# format
#     - No datetime found in column B
#
#   GS606-sGluc_COMPLETE.xlsx | GS606
#     - Title 'GS606' failed to parse: String 'GS606' doesn't match expected GBX###P# format
#
#   GS607-sGluc_REQ.RE-INJ.xlsx | GS607
#     - Title 'GS607' failed to parse: String 'GS607' doesn't match expected GBX###P# format
#
#   GS607-sGluc_REQ.RE-INJ.xlsx | GS1607
#     - Title 'GS1607' failed to parse: String 'GS1607' doesn't match expected GBX###P# format
#
#   GS609-sGluc_COMPLETE.xlsx | GS609
#     - Title 'GS609' failed to parse: String 'GS609' doesn't match expected GBX###P# format
#
#   GS611-sGluc_ENDED.xlsx | GS611
#     - Title 'GS611' failed to parse: String 'GS611' doesn't match expected GBX###P# format
#
#   GS619-sGluc_ENDED.xlsx | GS619
#     - Title 'GS619' failed to parse: String 'GS619' doesn't match expected GBX###P# format
#     - Row 19: 10 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS621-sGluc_COMPLETE.xlsx | GS621
#     - Title 'GS621' failed to parse: String 'GS621' doesn't match expected GBX###P# format
#
#   GS626-sGluc_ENDED.xlsx | GS626
#     - Title 'GS626' failed to parse: String 'GS626' doesn't match expected GBX###P# format
#
#   GS627-sGluc.xlsx | GS627
#     - Title 'GS627' failed to parse: String 'GS627' doesn't match expected GBX###P# format
#
#   GS629-sGluc.xlsx | Sheet1
#     - Title 'Sheet1' failed to parse: String 'Sheet1' doesn't match expected GBX###P# format
#     - No datetime found in column B
#
#   GS631-sGluc_ENDED.xlsx | GS631
#     - Title 'GS631' failed to parse: String 'GS631' doesn't match expected GBX###P# format
#     - Row 23: 4 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)
#
#   GS633-sGluc_COMPLETE.xlsx | Sheet1
#     - Title 'Sheet1' failed to parse: String 'Sheet1' doesn't match expected GBX###P# format
#     - No datetime found in column B
#
#   GS635-sGluc.xlsx | GBX635P0
#     - Row 24: 8 data columns found before dividing gap, not divisible by 3 (check for a missing/extra replicate or stray value)

# %%
def scan_row(ws, row_num):
    """
    Forward scan from DATA_START_COL looking for a "dividing None":
      (a) a None sandwiched between two non-None cells, or
      (b) a None that starts a run of Nones through the end of the row
          (i.e. the sheet just ran out of data).
    Returns (has_divider, values) where values are the real values
    collected before the divider.
    """
    values = []
    has_divider = False

    for col_index in range(DATA_START_COL, ws.max_column + 1):
        target_cell = ws.cell(row=row_num, column=col_index)

        if target_cell.value is None:
            prev_cell = (ws.cell(row=row_num, column=col_index - 1)
                         if col_index > DATA_START_COL else None)
            next_cell = (ws.cell(row=row_num, column=col_index + 1)
                         if col_index < ws.max_column else None)

            # Case A: sandwiched between two real values
            sandwiched = (prev_cell is not None and prev_cell.value is not None
                          and next_cell is not None and next_cell.value is not None)

            # Case B: this None, and everything after it, is None -> data ended
            rest_is_none = all(
                ws.cell(row=row_num, column=c).value is None
                for c in range(col_index, ws.max_column + 1)
            )

            if sandwiched or rest_is_none:
                has_divider = True
                break
            else:
                # a None that's neither sandwiched nor the start of the
                # trailing blank run - just skip it, don't record it
                continue

        values.append(target_cell.value)

    return has_divider, values

# %%
def scan_row(ws, row_num):
    """
    Replicates the ingestion script's forward scan from column C, looking
    for the "dividing None" (a None flanked by non-None cells on both
    sides). Returns (has_divider, values) where values are the real
    values collected before the divider (or before running off the end
    of the row, if no divider was found).
    """
    values = []
    has_divider = False
    for col_index in range(DATA_START_COL, ws.max_column + 1):
        target_cell = ws.cell(row=row_num, column=col_index)
        next_cell = ws.cell(row=row_num, column=col_index + 1)
        prev_cell = ws.cell(row=row_num, column=col_index - 1)
        first_nine = [ws.cell(row=row_num, column=c).value for c in range(3, 12)]
                if not any(isinstance(v, (int, float)) for v in first_nine):
                    print(f"Row {row_num} has no numeric values in first 9 columns, skipping")
                    continue
        if (target_cell.value is None
                and next_cell.value is not None
                and prev_cell.value is not None):
            has_divider = True
            break
        values.append(target_cell.value)
    return has_divider, values
